# %%
from newlk_search import *

# %% [markdown]
# Welcome to the new search module to peruse available data products for the TESS, Kepler, and K2 missions!
#
# This notebook will guide you through several examples of how to use search functions. The result of the search is a MASTSearch object, which contains among other things a full list of results stored in a pandas dataframe.
#
# *NOTE: While MASTSearch is a usable class, it does not have all of the functionality or nicities of the mission-specific searches (TESSSearch/KeplerSearch/K2Search). It is therefore recommended you as the user interact with these instead.*

# %%
# Does my target have any Kepler data?
Kep186 = KeplerSearch('Kepler 186')
Kep186
# Out:
#                      target_name    pipeline mission quarter   exptime  \
# 0                  kplr008120608      Kepler  Kepler       7    60.000
# 1                  kplr008120608      Kepler  Kepler       7    60.000
# 2                  kplr008120608      Kepler  Kepler       7    60.000
# 3                  kplr008120608      Kepler  Kepler       7    60.000
# 4                  kplr008120608      Kepler  Kepler       7    60.000
# ..                           ...         ...     ...     ...       ...
# 88                 kplr008120608      Kepler  Kepler      17  1800.000
# 89                 kplr008120608      Kepler  Kepler      15  1800.000
# 90                 kplr008120608      Kepler  Kepler      16  1800.000
# 91                 kplr008120608      Kepler  Kepler      17  1800.000
# 92  Gaia DR3 2079000330051813504  KBONUS-BKG    HLSP    <NA>  1765.464
#
#     distance  year                            description
# 0        0.0  2010    Lightcurve Short Cadence (CSC) - Q7
# 1        0.0  2010    Lightcurve Short Cadence (CSC) - Q7
# 2        0.0  2010    Lightcurve Short Cadence (CSC) - Q7
# 3        0.0  2010  Target Pixel Short Cadence (TPS) - Q7
# 4        0.0  2010  Target Pixel Short Cadence (TPS) - Q7
# ..       ...   ...                                    ...
# 88       0.0  2013    Lightcurve Long Cadence (CLC) - Q17
# 89       0.0  2013  Target Pixel Long Cadence (TPL) - Q15
# 90       0.0  2013  Target Pixel Long Cadence (TPL) - Q16
# 91       0.0  2013  Target Pixel Long Cadence (TPL) - Q17
# 92       0.0  2009                                   FITS
#
# [93 rows x 8 columns]

# %%
# This example shows what looks like duplicates, but they do have different file references
for key in Kep186.table.keys():
    print (f"{key}:  \t{Kep186.table.iloc[0][key]} \t {Kep186.table.iloc[1][key]}")
# Out:
# obs_index:  	1 	 1
# prod_index:  	13 	 14
# intentType:  	science 	 science
# obs_collection_obs:  	Kepler 	 Kepler
# provenance_name:  	Kepler 	 Kepler
# instrument_name:  	Kepler 	 Kepler
# project_obs:  	Kepler 	 Kepler
# filters:  	KEPLER 	 KEPLER
# wavelength_region:  	OPTICAL 	 OPTICAL
# target_name:  	kplr008120608 	 kplr008120608
# target_classification:  	nan 	 nan
# obs_id:  	kplr008120608_sc_Q000000033300333332 	 kplr008120608_sc_Q000000033300333332
# s_ra:  	298.65272000000004 	 298.65272000000004
# s_dec:  	43.95502 	 43.95502
# dataproduct_type_obs:  	timeseries 	 timeseries
# proposal_pi:  	William Borucki 	 William Borucki
# calib_level_obs:  	2 	 2
# t_min:  	54964.01041666667 	 54964.01041666667
# t_max:  	56423.510416666664 	 56423.510416666664
# exptime:  	60.0 	 60.0
# em_min:  	418400000000.0 	 418400000000.0
# em_max:  	905000000000.0 	 905000000000.0
# obs_title:  	Kepler Key Project 	 Kepler Key Project
# t_obs_release:  	nan 	 nan
# proposal_id_obs:  	EX 	 EX
# proposal_type:  	Kepler 	 Kepler
# sequence_number:  	7 	 7
# s_region:  	POLYGON ICRS 298.64963328 43.95724200 298.64963351 43.95279800 298.65580649 43.95279800 298.65580672 43.95724200 	 POLYGON ICRS 298.64963328 43.95724200 298.64963351 43.95279800 298.65580649 43.95279800 298.65580672 43.95724200
# jpegURL:  	http://archive.stsci.edu/missions/kepler/previews/0081/008120608/kplr008120608-2013017113907_slc_bw_large.png 	 http://archive.stsci.edu/missions/kepler/previews/0081/008120608/kplr008120608-2013017113907_slc_bw_large.png
# dataURL:  	http://archive.stsci.edu/missions/kepler/lightcurves/0081/008120608/kplr008120608_sc_Q000000033300333332.tar 	 http://archive.stsci.edu/missions/kepler/lightcurves/0081/008120608/kplr008120608_sc_Q000000033300333332.tar
# dataRights_obs:  	PUBLIC 	 PUBLIC
# mtFlag:  	nan 	 nan
# srcDen:  	5885.0 	 5885.0
# obsid:  	390695 	 390695
# objID:  	617573 	 617573
# objID1:  	617573 	 617573
# distance:  	0.0 	 0.0
# obsID:  	390695 	 390695
# obs_collection:  	Kepler 	 Kepler
# dataproduct_type:  	timeseries 	 timeseries
# description:  	Lightcurve Short Cadence (CSC) - Q7 	 Lightcurve Short Cadence (CSC) - Q7
# type:  	C 	 C
# dataURI:  	mast:KEPLER/url/missions/kepler/lightcurves/0081/008120608/kplr008120608-2010296114515_slc.fits 	 mast:KEPLER/url/missions/kepler/lightcurves/0081/008120608/kplr008120608-2010326094124_slc.fits
# productType:  	SCIENCE 	 SCIENCE
# productGroupDescription:  	Minimum Recommended Products 	 Minimum Recommended Products
# productSubGroupDescription:  	SLC 	 SLC
# productDocumentationURL:  	nan 	 nan
# project:  	Kepler 	 Kepler
# prvversion:  	nan 	 nan
# proposal_id:  	EX 	 EX
# productFilename:  	kplr008120608-2010296114515_slc.fits 	 kplr008120608-2010326094124_slc.fits
# size:  	4452480 	 4317120
# parent_obsid:  	390695 	 390695
# dataRights:  	PUBLIC 	 PUBLIC
# calib_level_prod:  	2 	 2
# pipeline:  	Kepler 	 Kepler
# mission:  	Kepler 	 Kepler
# year:  	2010 	 2010
# start_time:  	2009-05-13 00:15:00.000 	 2009-05-13 00:15:00.000
# end_time:  	2013-05-11 12:15:00.000 	 2013-05-11 12:15:00.000
# mission_product:  	True 	 True
# quarter:  	7 	 7
# sort_order:  	1 	 1

# %% [markdown]
# The call to KeplerSearch saves all availabe data products for the target as a table. This can be useful for data exploration, but in some cases, the user may only want to access specific data types. Search has several convenient functions to limit the results to timeseries (lighcurve), cubedata (target pixel files and, in the case of TESS, full frame image cutouts), and dvreports (PDF data validation reports generated by the data pipelines). Calling these functions returns a new search object.

# %%
# What timeseries data is available?
lcs = Kep186.timeseries
lcs
# Out:
#                      target_name    pipeline mission quarter   exptime  \
# 0                  kplr008120608      Kepler  Kepler       7    60.000
# 1                  kplr008120608      Kepler  Kepler       7    60.000
# 2                  kplr008120608      Kepler  Kepler       7    60.000
# 3                  kplr008120608      Kepler  Kepler       8    60.000
# 4                  kplr008120608      Kepler  Kepler       8    60.000
# 5                  kplr008120608      Kepler  Kepler       8    60.000
# 6                  kplr008120608      Kepler  Kepler       9    60.000
# 7                  kplr008120608      Kepler  Kepler       9    60.000
# 8                  kplr008120608      Kepler  Kepler       9    60.000
# 9                  kplr008120608      Kepler  Kepler      12    60.000
# 10                 kplr008120608      Kepler  Kepler      12    60.000
# 11                 kplr008120608      Kepler  Kepler      12    60.000
# 12                 kplr008120608      Kepler  Kepler      13    60.000
# 13                 kplr008120608      Kepler  Kepler      13    60.000
# 14                 kplr008120608      Kepler  Kepler      13    60.000
# 15                 kplr008120608      Kepler  Kepler      14    60.000
# 16                 kplr008120608      Kepler  Kepler      14    60.000
# 17                 kplr008120608      Kepler  Kepler      14    60.000
# 18                 kplr008120608      Kepler  Kepler      15    60.000
# 19                 kplr008120608      Kepler  Kepler      15    60.000
# 20                 kplr008120608      Kepler  Kepler      15    60.000
# 21                 kplr008120608      Kepler  Kepler      16    60.000
# 22                 kplr008120608      Kepler  Kepler      16    60.000
# 23                 kplr008120608      Kepler  Kepler      16    60.000
# 24                 kplr008120608      Kepler  Kepler      17    60.000
# 25                 kplr008120608      Kepler  Kepler      17    60.000
# 26                 kplr008120608      Kepler  Kepler       1  1800.000
# 27                 kplr008120608      Kepler  Kepler       2  1800.000
# 28                 kplr008120608      Kepler  Kepler       3  1800.000
# 29                 kplr008120608      Kepler  Kepler       4  1800.000
# 30                 kplr008120608      Kepler  Kepler       5  1800.000
# 31                 kplr008120608      Kepler  Kepler       6  1800.000
# 32                 kplr008120608      Kepler  Kepler       7  1800.000
# 33                 kplr008120608      Kepler  Kepler       8  1800.000
# 34                 kplr008120608      Kepler  Kepler       9  1800.000
# 35                 kplr008120608      Kepler  Kepler      10  1800.000
# 36                 kplr008120608      Kepler  Kepler      11  1800.000
# 37                 kplr008120608      Kepler  Kepler      12  1800.000
# 38                 kplr008120608      Kepler  Kepler      13  1800.000
# 39                 kplr008120608      Kepler  Kepler      14  1800.000
# 40                 kplr008120608      Kepler  Kepler      15  1800.000
# 41                 kplr008120608      Kepler  Kepler      16  1800.000
# 42                 kplr008120608      Kepler  Kepler      17  1800.000
# 43  Gaia DR3 2079000330051813504  KBONUS-BKG    HLSP    <NA>  1765.464
#
#     distance  year                           description
# 0        0.0  2010   Lightcurve Short Cadence (CSC) - Q7
# 1        0.0  2010   Lightcurve Short Cadence (CSC) - Q7
# 2        0.0  2010   Lightcurve Short Cadence (CSC) - Q7
# 3        0.0  2011   Lightcurve Short Cadence (CSC) - Q8
# 4        0.0  2011   Lightcurve Short Cadence (CSC) - Q8
# 5        0.0  2011   Lightcurve Short Cadence (CSC) - Q8
# 6        0.0  2011   Lightcurve Short Cadence (CSC) - Q9
# 7        0.0  2011   Lightcurve Short Cadence (CSC) - Q9
# 8        0.0  2011   Lightcurve Short Cadence (CSC) - Q9
# 9        0.0  2012  Lightcurve Short Cadence (CSC) - Q12
# 10       0.0  2012  Lightcurve Short Cadence (CSC) - Q12
# 11       0.0  2012  Lightcurve Short Cadence (CSC) - Q12
# 12       0.0  2012  Lightcurve Short Cadence (CSC) - Q13
# 13       0.0  2012  Lightcurve Short Cadence (CSC) - Q13
# 14       0.0  2012  Lightcurve Short Cadence (CSC) - Q13
# 15       0.0  2012  Lightcurve Short Cadence (CSC) - Q14
# 16       0.0  2012  Lightcurve Short Cadence (CSC) - Q14
# 17       0.0  2012  Lightcurve Short Cadence (CSC) - Q14
# 18       0.0  2012  Lightcurve Short Cadence (CSC) - Q15
# 19       0.0  2012  Lightcurve Short Cadence (CSC) - Q15
# 20       0.0  2013  Lightcurve Short Cadence (CSC) - Q15
# 21       0.0  2013  Lightcurve Short Cadence (CSC) - Q16
# 22       0.0  2013  Lightcurve Short Cadence (CSC) - Q16
# 23       0.0  2013  Lightcurve Short Cadence (CSC) - Q16
# 24       0.0  2013  Lightcurve Short Cadence (CSC) - Q17
# 25       0.0  2013  Lightcurve Short Cadence (CSC) - Q17
# 26       0.0  2009    Lightcurve Long Cadence (CLC) - Q1
# 27       0.0  2009    Lightcurve Long Cadence (CLC) - Q2
# 28       0.0  2009    Lightcurve Long Cadence (CLC) - Q3
# 29       0.0  2010    Lightcurve Long Cadence (CLC) - Q4
# 30       0.0  2010    Lightcurve Long Cadence (CLC) - Q5
# 31       0.0  2010    Lightcurve Long Cadence (CLC) - Q6
# 32       0.0  2010    Lightcurve Long Cadence (CLC) - Q7
# 33       0.0  2011    Lightcurve Long Cadence (CLC) - Q8
# 34       0.0  2011    Lightcurve Long Cadence (CLC) - Q9
# 35       0.0  2011   Lightcurve Long Cadence (CLC) - Q10
# 36       0.0  2012   Lightcurve Long Cadence (CLC) - Q11
# 37       0.0  2012   Lightcurve Long Cadence (CLC) - Q12
# 38       0.0  2012   Lightcurve Long Cadence (CLC) - Q13
# 39       0.0  2012   Lightcurve Long Cadence (CLC) - Q14
# 40       0.0  2013   Lightcurve Long Cadence (CLC) - Q15
# 41       0.0  2013   Lightcurve Long Cadence (CLC) - Q16
# 42       0.0  2013   Lightcurve Long Cadence (CLC) - Q17
# 43       0.0  2009                                  FITS

# %%
# What cubedata data is available? 
tpfs = Kep186.cubedata
tpfs
# Out:
#       target_name pipeline mission quarter  exptime  distance  year  \
# 0   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 1   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 2   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 3   kplr008120608   Kepler  Kepler       8     60.0       0.0  2011
# 4   kplr008120608   Kepler  Kepler       8     60.0       0.0  2011
# 5   kplr008120608   Kepler  Kepler       8     60.0       0.0  2011
# 6   kplr008120608   Kepler  Kepler       9     60.0       0.0  2011
# 7   kplr008120608   Kepler  Kepler       9     60.0       0.0  2011
# 8   kplr008120608   Kepler  Kepler       9     60.0       0.0  2011
# 9   kplr008120608   Kepler  Kepler      12     60.0       0.0  2012
# 10  kplr008120608   Kepler  Kepler      12     60.0       0.0  2012
# 11  kplr008120608   Kepler  Kepler      12     60.0       0.0  2012
# 12  kplr008120608   Kepler  Kepler      13     60.0       0.0  2012
# 13  kplr008120608   Kepler  Kepler      13     60.0       0.0  2012
# 14  kplr008120608   Kepler  Kepler      13     60.0       0.0  2012
# 15  kplr008120608   Kepler  Kepler      14     60.0       0.0  2012
# 16  kplr008120608   Kepler  Kepler      14     60.0       0.0  2012
# 17  kplr008120608   Kepler  Kepler      14     60.0       0.0  2012
# 18  kplr008120608   Kepler  Kepler      15     60.0       0.0  2012
# 19  kplr008120608   Kepler  Kepler      15     60.0       0.0  2012
# 20  kplr008120608   Kepler  Kepler      15     60.0       0.0  2013
# 21  kplr008120608   Kepler  Kepler      16     60.0       0.0  2013
# 22  kplr008120608   Kepler  Kepler      16     60.0       0.0  2013
# 23  kplr008120608   Kepler  Kepler      16     60.0       0.0  2013
# 24  kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
# 25  kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
# 26  kplr008120608   Kepler  Kepler       1   1800.0       0.0  2009
# 27  kplr008120608   Kepler  Kepler       2   1800.0       0.0  2009
# 28  kplr008120608   Kepler  Kepler       3   1800.0       0.0  2009
# 29  kplr008120608   Kepler  Kepler       4   1800.0       0.0  2010
# 30  kplr008120608   Kepler  Kepler       5   1800.0       0.0  2010
# 31  kplr008120608   Kepler  Kepler       6   1800.0       0.0  2010
# 32  kplr008120608   Kepler  Kepler       7   1800.0       0.0  2010
# 33  kplr008120608   Kepler  Kepler       8   1800.0       0.0  2011
# 34  kplr008120608   Kepler  Kepler       9   1800.0       0.0  2011
# 35  kplr008120608   Kepler  Kepler      10   1800.0       0.0  2011
# 36  kplr008120608   Kepler  Kepler      11   1800.0       0.0  2012
# 37  kplr008120608   Kepler  Kepler      12   1800.0       0.0  2012
# 38  kplr008120608   Kepler  Kepler      13   1800.0       0.0  2012
# 39  kplr008120608   Kepler  Kepler      14   1800.0       0.0  2012
# 40  kplr008120608   Kepler  Kepler      15   1800.0       0.0  2013
# 41  kplr008120608   Kepler  Kepler      16   1800.0       0.0  2013
# 42  kplr008120608   Kepler  Kepler      17   1800.0       0.0  2013
#
#                                description
# 0    Target Pixel Short Cadence (TPS) - Q7
# 1    Target Pixel Short Cadence (TPS) - Q7
# 2    Target Pixel Short Cadence (TPS) - Q7
# 3    Target Pixel Short Cadence (TPS) - Q8
# 4    Target Pixel Short Cadence (TPS) - Q8
# 5    Target Pixel Short Cadence (TPS) - Q8
# 6    Target Pixel Short Cadence (TPS) - Q9
# 7    Target Pixel Short Cadence (TPS) - Q9
# 8    Target Pixel Short Cadence (TPS) - Q9
# 9   Target Pixel Short Cadence (TPS) - Q12
# 10  Target Pixel Short Cadence (TPS) - Q12
# 11  Target Pixel Short Cadence (TPS) - Q12
# 12  Target Pixel Short Cadence (TPS) - Q13
# 13  Target Pixel Short Cadence (TPS) - Q13
# 14  Target Pixel Short Cadence (TPS) - Q13
# 15  Target Pixel Short Cadence (TPS) - Q14
# 16  Target Pixel Short Cadence (TPS) - Q14
# 17  Target Pixel Short Cadence (TPS) - Q14
# 18  Target Pixel Short Cadence (TPS) - Q15
# 19  Target Pixel Short Cadence (TPS) - Q15
# 20  Target Pixel Short Cadence (TPS) - Q15
# 21  Target Pixel Short Cadence (TPS) - Q16
# 22  Target Pixel Short Cadence (TPS) - Q16
# 23  Target Pixel Short Cadence (TPS) - Q16
# 24  Target Pixel Short Cadence (TPS) - Q17
# 25  Target Pixel Short Cadence (TPS) - Q17
# 26    Target Pixel Long Cadence (TPL) - Q1
# 27    Target Pixel Long Cadence (TPL) - Q2
# 28    Target Pixel Long Cadence (TPL) - Q3
# 29    Target Pixel Long Cadence (TPL) - Q4
# 30    Target Pixel Long Cadence (TPL) - Q5
# 31    Target Pixel Long Cadence (TPL) - Q6
# 32    Target Pixel Long Cadence (TPL) - Q7
# 33    Target Pixel Long Cadence (TPL) - Q8
# 34    Target Pixel Long Cadence (TPL) - Q9
# 35   Target Pixel Long Cadence (TPL) - Q10
# 36   Target Pixel Long Cadence (TPL) - Q11
# 37   Target Pixel Long Cadence (TPL) - Q12
# 38   Target Pixel Long Cadence (TPL) - Q13
# 39   Target Pixel Long Cadence (TPL) - Q14
# 40   Target Pixel Long Cadence (TPL) - Q15
# 41   Target Pixel Long Cadence (TPL) - Q16
# 42   Target Pixel Long Cadence (TPL) - Q17

# %%
# Check if data validation reports were generated for this star
dvs = Kep186.dvreports
dvs
# Out:
#      target_name pipeline mission quarter  exptime  distance  year  \
# 0  kplr008120608   Kepler  Kepler    <NA>   1800.0       0.0  2009
# 1  kplr008120608   Kepler  Kepler    <NA>   1800.0       0.0  2009
# 2  kplr008120608   Kepler  Kepler    <NA>   1800.0       0.0  2009
# 3  kplr008120608   Kepler  Kepler    <NA>   1800.0       0.0  2009
# 4  kplr008120608   Kepler  Kepler    <NA>   1800.0       0.0  2009
# 5  kplr008120608   Kepler  Kepler    <NA>   1800.0       0.0  2009
#
#                       description
# 0  Data Validation summary report
# 1  Data Validation summary report
# 2  Data Validation summary report
# 3  Data Validation summary report
# 4  Data Validation summary report
# 5     Data Validation full report

# %%
# There is a lot of data for this target. Let's limit it to short cadence data
Kep186short = Kep186.filter_table(exptime=60)
Kep186short
# Out:
#       target_name pipeline mission quarter  exptime  distance  year  \
# 0   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 1   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 2   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 3   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 4   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 5   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 6   kplr008120608   Kepler  Kepler       8     60.0       0.0  2011
# 7   kplr008120608   Kepler  Kepler       8     60.0       0.0  2011
# 8   kplr008120608   Kepler  Kepler       8     60.0       0.0  2011
# 9   kplr008120608   Kepler  Kepler       9     60.0       0.0  2011
# 10  kplr008120608   Kepler  Kepler       9     60.0       0.0  2011
# 11  kplr008120608   Kepler  Kepler       9     60.0       0.0  2011
# 12  kplr008120608   Kepler  Kepler       8     60.0       0.0  2011
# 13  kplr008120608   Kepler  Kepler       8     60.0       0.0  2011
# 14  kplr008120608   Kepler  Kepler       8     60.0       0.0  2011
# 15  kplr008120608   Kepler  Kepler       9     60.0       0.0  2011
# 16  kplr008120608   Kepler  Kepler       9     60.0       0.0  2011
# 17  kplr008120608   Kepler  Kepler       9     60.0       0.0  2011
# 18  kplr008120608   Kepler  Kepler      12     60.0       0.0  2012
# 19  kplr008120608   Kepler  Kepler      12     60.0       0.0  2012
# 20  kplr008120608   Kepler  Kepler      12     60.0       0.0  2012
# 21  kplr008120608   Kepler  Kepler      13     60.0       0.0  2012
# 22  kplr008120608   Kepler  Kepler      13     60.0       0.0  2012
# 23  kplr008120608   Kepler  Kepler      13     60.0       0.0  2012
# 24  kplr008120608   Kepler  Kepler      14     60.0       0.0  2012
# 25  kplr008120608   Kepler  Kepler      14     60.0       0.0  2012
# 26  kplr008120608   Kepler  Kepler      14     60.0       0.0  2012
# 27  kplr008120608   Kepler  Kepler      15     60.0       0.0  2012
# 28  kplr008120608   Kepler  Kepler      15     60.0       0.0  2012
# 29  kplr008120608   Kepler  Kepler      12     60.0       0.0  2012
# 30  kplr008120608   Kepler  Kepler      12     60.0       0.0  2012
# 31  kplr008120608   Kepler  Kepler      12     60.0       0.0  2012
# 32  kplr008120608   Kepler  Kepler      13     60.0       0.0  2012
# 33  kplr008120608   Kepler  Kepler      13     60.0       0.0  2012
# 34  kplr008120608   Kepler  Kepler      13     60.0       0.0  2012
# 35  kplr008120608   Kepler  Kepler      14     60.0       0.0  2012
# 36  kplr008120608   Kepler  Kepler      14     60.0       0.0  2012
# 37  kplr008120608   Kepler  Kepler      14     60.0       0.0  2012
# 38  kplr008120608   Kepler  Kepler      15     60.0       0.0  2012
# 39  kplr008120608   Kepler  Kepler      15     60.0       0.0  2012
# 40  kplr008120608   Kepler  Kepler      15     60.0       0.0  2013
# 41  kplr008120608   Kepler  Kepler      16     60.0       0.0  2013
# 42  kplr008120608   Kepler  Kepler      16     60.0       0.0  2013
# 43  kplr008120608   Kepler  Kepler      16     60.0       0.0  2013
# 44  kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
# 45  kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
# 46  kplr008120608   Kepler  Kepler      15     60.0       0.0  2013
# 47  kplr008120608   Kepler  Kepler      16     60.0       0.0  2013
# 48  kplr008120608   Kepler  Kepler      16     60.0       0.0  2013
# 49  kplr008120608   Kepler  Kepler      16     60.0       0.0  2013
# 50  kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
# 51  kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
#
#                                description
# 0      Lightcurve Short Cadence (CSC) - Q7
# 1      Lightcurve Short Cadence (CSC) - Q7
# 2      Lightcurve Short Cadence (CSC) - Q7
# 3    Target Pixel Short Cadence (TPS) - Q7
# 4    Target Pixel Short Cadence (TPS) - Q7
# 5    Target Pixel Short Cadence (TPS) - Q7
# 6      Lightcurve Short Cadence (CSC) - Q8
# 7      Lightcurve Short Cadence (CSC) - Q8
# 8      Lightcurve Short Cadence (CSC) - Q8
# 9      Lightcurve Short Cadence (CSC) - Q9
# 10     Lightcurve Short Cadence (CSC) - Q9
# 11     Lightcurve Short Cadence (CSC) - Q9
# 12   Target Pixel Short Cadence (TPS) - Q8
# 13   Target Pixel Short Cadence (TPS) - Q8
# 14   Target Pixel Short Cadence (TPS) - Q8
# 15   Target Pixel Short Cadence (TPS) - Q9
# 16   Target Pixel Short Cadence (TPS) - Q9
# 17   Target Pixel Short Cadence (TPS) - Q9
# 18    Lightcurve Short Cadence (CSC) - Q12
# 19    Lightcurve Short Cadence (CSC) - Q12
# 20    Lightcurve Short Cadence (CSC) - Q12
# 21    Lightcurve Short Cadence (CSC) - Q13
# 22    Lightcurve Short Cadence (CSC) - Q13
# 23    Lightcurve Short Cadence (CSC) - Q13
# 24    Lightcurve Short Cadence (CSC) - Q14
# 25    Lightcurve Short Cadence (CSC) - Q14
# 26    Lightcurve Short Cadence (CSC) - Q14
# 27    Lightcurve Short Cadence (CSC) - Q15
# 28    Lightcurve Short Cadence (CSC) - Q15
# 29  Target Pixel Short Cadence (TPS) - Q12
# 30  Target Pixel Short Cadence (TPS) - Q12
# 31  Target Pixel Short Cadence (TPS) - Q12
# 32  Target Pixel Short Cadence (TPS) - Q13
# 33  Target Pixel Short Cadence (TPS) - Q13
# 34  Target Pixel Short Cadence (TPS) - Q13
# 35  Target Pixel Short Cadence (TPS) - Q14
# 36  Target Pixel Short Cadence (TPS) - Q14
# 37  Target Pixel Short Cadence (TPS) - Q14
# 38  Target Pixel Short Cadence (TPS) - Q15
# 39  Target Pixel Short Cadence (TPS) - Q15
# 40    Lightcurve Short Cadence (CSC) - Q15
# 41    Lightcurve Short Cadence (CSC) - Q16
# 42    Lightcurve Short Cadence (CSC) - Q16
# 43    Lightcurve Short Cadence (CSC) - Q16
# 44    Lightcurve Short Cadence (CSC) - Q17
# 45    Lightcurve Short Cadence (CSC) - Q17
# 46  Target Pixel Short Cadence (TPS) - Q15
# 47  Target Pixel Short Cadence (TPS) - Q16
# 48  Target Pixel Short Cadence (TPS) - Q16
# 49  Target Pixel Short Cadence (TPS) - Q16
# 50  Target Pixel Short Cadence (TPS) - Q17
# 51  Target Pixel Short Cadence (TPS) - Q17

# %%
# we can also filter the results by observing quarter
Kep186_Q = Kep186.filter_table(quarter=[7,17])
Kep186_Q
# Out:
#       target_name pipeline mission quarter  exptime  distance  year  \
# 0   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 1   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 2   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 3   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 4   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 5   kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 6   kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
# 7   kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
# 8   kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
# 9   kplr008120608   Kepler  Kepler      17     60.0       0.0  2013
# 10  kplr008120608   Kepler  Kepler       7   1800.0       0.0  2010
# 11  kplr008120608   Kepler  Kepler       7   1800.0       0.0  2010
# 12  kplr008120608   Kepler  Kepler      17   1800.0       0.0  2013
# 13  kplr008120608   Kepler  Kepler      17   1800.0       0.0  2013
#
#                                description
# 0      Lightcurve Short Cadence (CSC) - Q7
# 1      Lightcurve Short Cadence (CSC) - Q7
# 2      Lightcurve Short Cadence (CSC) - Q7
# 3    Target Pixel Short Cadence (TPS) - Q7
# 4    Target Pixel Short Cadence (TPS) - Q7
# 5    Target Pixel Short Cadence (TPS) - Q7
# 6     Lightcurve Short Cadence (CSC) - Q17
# 7     Lightcurve Short Cadence (CSC) - Q17
# 8   Target Pixel Short Cadence (TPS) - Q17
# 9   Target Pixel Short Cadence (TPS) - Q17
# 10      Lightcurve Long Cadence (CLC) - Q7
# 11    Target Pixel Long Cadence (TPL) - Q7
# 12     Lightcurve Long Cadence (CLC) - Q17
# 13   Target Pixel Long Cadence (TPL) - Q17

# %%
Kep186_Q17_short = Kep186.filter_table(quarter=7, exptime=60)
Kep186_Q17_short
# Out:
#      target_name pipeline mission quarter  exptime  distance  year  \
# 0  kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 1  kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 2  kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 3  kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 4  kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
# 5  kplr008120608   Kepler  Kepler       7     60.0       0.0  2010
#
#                              description
# 0    Lightcurve Short Cadence (CSC) - Q7
# 1    Lightcurve Short Cadence (CSC) - Q7
# 2    Lightcurve Short Cadence (CSC) - Q7
# 3  Target Pixel Short Cadence (TPS) - Q7
# 4  Target Pixel Short Cadence (TPS) - Q7
# 5  Target Pixel Short Cadence (TPS) - Q7

# %%
result = TESSSearch("Au Mic")
result
# Out:
#    target_name           pipeline         mission  sector  exptime  distance  \
# 0    441420236               SPOC            TESS       1    120.0       0.0
# 1    441420236               SPOC            TESS       1    120.0       0.0
# 2    441420236               SPOC            TESS       1    120.0       0.0
# 3    441420236               SPOC            TESS       1    120.0       0.0
# 4    441420236               SPOC            TESS       1    120.0       0.0
# 5    441420236               SPOC            TESS       1    120.0       0.0
# 6    441420236               SPOC            TESS       1    120.0       0.0
# 7    441420236               SPOC            TESS       1    120.0       0.0
# 8    441420236               SPOC            TESS       1    120.0       0.0
# 9    441420236               SPOC            TESS       1    120.0       0.0
# 10   441420236               SPOC            TESS       1    120.0       0.0
# 11   441420236               SPOC            TESS       1    120.0       0.0
# 12   441420236               SPOC            TESS       1    120.0       0.0
# 13   441420236               SPOC            TESS       1    120.0       0.0
# 14   441420236               SPOC            TESS       1    120.0       0.0
# 15   441420236               SPOC            TESS       1    120.0       0.0
# 16   441420236               SPOC            TESS      27     20.0       0.0
# 17   441420236               SPOC            TESS      27     20.0       0.0
# 18   441420236               SPOC            TESS      27    120.0       0.0
# 19   441420236               SPOC            TESS      27    120.0       0.0
# 20   441420236               SPOC            TESS      27    120.0       0.0
# 21   441420236               SPOC            TESS      27    120.0       0.0
# 22   441420236               SPOC            TESS      27    120.0       0.0
# 23   441420236               SPOC            TESS      27    120.0       0.0
# 24   441420236               SPOC            TESS      36    120.0       0.0
# 25   441420236               SPOC            TESS      36    120.0       0.0
# 26   441420236               SPOC            TESS      36    120.0       0.0
# 27   441420236               SPOC            TESS      36    120.0       0.0
# 28   441420236               SPOC            TESS      36    120.0       0.0
# 29   441420236               SPOC            TESS      36    120.0       0.0
# 30   441420236               SPOC            TESS      36    120.0       0.0
# 31   441420236               SPOC            TESS      36    120.0       0.0
# 32   441420236          TESS-SPOC            HLSP       1   1800.0       0.0
# 33   441420236          TESS-SPOC            HLSP       1   1800.0       0.0
# 34   441420236          TESS-SPOC            HLSP      27    600.0       0.0
# 35   441420236          TESS-SPOC            HLSP      27    600.0       0.0
# 36      Au Mic            TESScut  TESS Sector 01       1   1800.0       0.0
# 37      Au Mic            TESScut  TESS Sector 27      27    600.0       0.0
# 38      Au Mic            TESScut  TESS Sector 95      95    200.0       0.0
# 39   441420236  GSFC-ELEANOR-LITE            HLSP       1   1800.0       0.0
# 40   441420236                QLP            HLSP       1   1800.0       0.0
# 41   441420236              TASOC            HLSP       1    120.0       0.0
# 42   441420236              TASOC            HLSP       1   1800.0       0.0
# 43   441420236              TASOC            HLSP       1   1800.0       0.0
# 44   441420236              CDIPS            HLSP      27   1800.0       0.0
# 45   441420236                QLP            HLSP      27    600.0       0.0
#
#     year                  description
# 0   2018  full data validation report
# 1   2018  full data validation report
# 2   2018  Data validation mini report
# 3   2018  Data validation mini report
# 4   2018           TCE summary report
# 5   2018           TCE summary report
# 6   2018           TCE summary report
# 7   2018           TCE summary report
# 8   2018           TCE summary report
# 9   2018           TCE summary report
# 10  2018           TCE summary report
# 11  2018           TCE summary report
# 12  2018           TCE summary report
# 13  2018           TCE summary report
# 14  2018                 Light curves
# 15  2018           Target pixel files
# 16  2020                 Light curves
# 17  2020           Target pixel files
# 18  2020  full data validation report
# 19  2020  Data validation mini report
# 20  2020           TCE summary report
# 21  2020           TCE summary report
# 22  2020                 Light curves
# 23  2020           Target pixel files
# 24  2018  full data validation report
# 25  2018  Data validation mini report
# 26  2018           TCE summary report
# 27  2018           TCE summary report
# 28  2018           TCE summary report
# 29  2018           TCE summary report
# 30  2018           TCE summary report
# 31  2018           TCE summary report
# 32  2018                         FITS
# 33  2018                         FITS
# 34  2020                         FITS
# 35  2020                         FITS
# 36  2018   TESS FFI Cutout (sector 1)
# 37  2020  TESS FFI Cutout (sector 27)
# 38  2025  TESS FFI Cutout (sector 95)
# 39  2018                         FITS
# 40  2018                         FITS
# 41  2018                         FITS
# 42  2018                         FITS
# 43  2018                         FITS
# 44  2020                         FITS
# 45  2020                         FITS

# %%
# TODO: the sorting doesn't happen for timeseries/cubedata/etc
result.timeseries
# Out:
#    target_name           pipeline mission  sector  exptime  distance  year  \
# 0    441420236               SPOC    TESS       1    120.0       0.0  2018
# 1    441420236               SPOC    TESS      27     20.0       0.0  2020
# 2    441420236               SPOC    TESS      27    120.0       0.0  2020
# 3    441420236          TESS-SPOC    HLSP       1   1800.0       0.0  2018
# 4    441420236          TESS-SPOC    HLSP      27    600.0       0.0  2020
# 5    441420236  GSFC-ELEANOR-LITE    HLSP       1   1800.0       0.0  2018
# 6    441420236                QLP    HLSP       1   1800.0       0.0  2018
# 7    441420236              TASOC    HLSP       1    120.0       0.0  2018
# 8    441420236              TASOC    HLSP       1   1800.0       0.0  2018
# 9    441420236              TASOC    HLSP       1   1800.0       0.0  2018
# 10   441420236              CDIPS    HLSP      27   1800.0       0.0  2020
# 11   441420236                QLP    HLSP      27    600.0       0.0  2020
#
#      description
# 0   Light curves
# 1   Light curves
# 2   Light curves
# 3           FITS
# 4           FITS
# 5           FITS
# 6           FITS
# 7           FITS
# 8           FITS
# 9           FITS
# 10          FITS
# 11          FITS

# %%
# Only get the PDF data validation reports
result.dvreports
# Out:
#    target_name pipeline mission  sector  exptime  distance  year  \
# 0    441420236     SPOC    TESS       1    120.0       0.0  2018
# 1    441420236     SPOC    TESS       1    120.0       0.0  2018
# 2    441420236     SPOC    TESS       1    120.0       0.0  2018
# 3    441420236     SPOC    TESS       1    120.0       0.0  2018
# 4    441420236     SPOC    TESS       1    120.0       0.0  2018
# 5    441420236     SPOC    TESS       1    120.0       0.0  2018
# 6    441420236     SPOC    TESS       1    120.0       0.0  2018
# 7    441420236     SPOC    TESS       1    120.0       0.0  2018
# 8    441420236     SPOC    TESS       1    120.0       0.0  2018
# 9    441420236     SPOC    TESS       1    120.0       0.0  2018
# 10   441420236     SPOC    TESS       1    120.0       0.0  2018
# 11   441420236     SPOC    TESS       1    120.0       0.0  2018
# 12   441420236     SPOC    TESS       1    120.0       0.0  2018
# 13   441420236     SPOC    TESS       1    120.0       0.0  2018
# 14   441420236     SPOC    TESS      27    120.0       0.0  2020
# 15   441420236     SPOC    TESS      27    120.0       0.0  2020
# 16   441420236     SPOC    TESS      27    120.0       0.0  2020
# 17   441420236     SPOC    TESS      27    120.0       0.0  2020
# 18   441420236     SPOC    TESS      36    120.0       0.0  2018
# 19   441420236     SPOC    TESS      36    120.0       0.0  2018
# 20   441420236     SPOC    TESS      36    120.0       0.0  2018
# 21   441420236     SPOC    TESS      36    120.0       0.0  2018
# 22   441420236     SPOC    TESS      36    120.0       0.0  2018
# 23   441420236     SPOC    TESS      36    120.0       0.0  2018
# 24   441420236     SPOC    TESS      36    120.0       0.0  2018
# 25   441420236     SPOC    TESS      36    120.0       0.0  2018
#
#                     description
# 0   full data validation report
# 1   full data validation report
# 2   Data validation mini report
# 3   Data validation mini report
# 4            TCE summary report
# 5            TCE summary report
# 6            TCE summary report
# 7            TCE summary report
# 8            TCE summary report
# 9            TCE summary report
# 10           TCE summary report
# 11           TCE summary report
# 12           TCE summary report
# 13           TCE summary report
# 14  full data validation report
# 15  Data validation mini report
# 16           TCE summary report
# 17           TCE summary report
# 18  full data validation report
# 19  Data validation mini report
# 20           TCE summary report
# 21           TCE summary report
# 22           TCE summary report
# 23           TCE summary report
# 24           TCE summary report
# 25           TCE summary report

# %%
sr = MASTSearch("Kepler 186")
sr
# Out:
#        target_name pipeline mission  exptime  distance  year  \
# 0        268159861     SPOC    TESS    120.0       0.0  2022
# 1        268159861     SPOC    TESS    120.0       0.0  2022
# 2        268159861     SPOC    TESS    120.0       0.0  2021
# 3        268159861     SPOC    TESS    120.0       0.0  2021
# 4        268159861     SPOC    TESS    120.0       0.0  2024
# ..             ...      ...     ...      ...       ...   ...
# 97   kplr008120608   Kepler  Kepler   1800.0       0.0  2012
# 98   kplr008120608   Kepler  Kepler   1800.0       0.0  2012
# 99   kplr008120608   Kepler  Kepler   1800.0       0.0  2013
# 100  kplr008120608   Kepler  Kepler   1800.0       0.0  2013
# 101  kplr008120608   Kepler  Kepler   1800.0       0.0  2013
#
#                                description
# 0                             Light curves
# 1                       Target pixel files
# 2                             Light curves
# 3                       Target pixel files
# 4                             Light curves
# ..                                     ...
# 97   Target Pixel Long Cadence (TPL) - Q13
# 98   Target Pixel Long Cadence (TPL) - Q14
# 99   Target Pixel Long Cadence (TPL) - Q15
# 100  Target Pixel Long Cadence (TPL) - Q16
# 101  Target Pixel Long Cadence (TPL) - Q17
#
# [102 rows x 7 columns]

# %%
K2_18 = K2Search("K2-18")
K2_18
# Out:
#      target_name  pipeline mission campaign  exptime  distance  year  \
# 0  ktwo201912552        K2      K2        1   1800.0       0.0  2014
# 1  ktwo201912552        K2      K2        1   1800.0       0.0  2014
# 2  ktwo201912552     K2SFF    HLSP        1   1800.0       0.0  2014
# 3  ktwo201912552   EVEREST    HLSP        1   1800.0       0.0  2014
# 4  ktwo201912552   EVEREST    HLSP        1   1800.0       0.0  2014
# 5  ktwo201912552  K2VARCAT    HLSP        1   1800.0       0.0  2014
#
#                              description
# 0    Lightcurve Long Cadence (KLC) - C01
# 1  Target Pixel Long Cadence (KTL) - C01
# 2                                   FITS
# 3                                   FITS
# 4                                    PDF
# 5                                   FITS

# %%
K2_18.filter_table(campaign = 1)
# Out:
#      target_name  pipeline mission campaign  exptime  distance  year  \
# 0  ktwo201912552        K2      K2        1   1800.0       0.0  2014
# 1  ktwo201912552        K2      K2        1   1800.0       0.0  2014
# 2  ktwo201912552     K2SFF    HLSP        1   1800.0       0.0  2014
# 3  ktwo201912552   EVEREST    HLSP        1   1800.0       0.0  2014
# 4  ktwo201912552   EVEREST    HLSP        1   1800.0       0.0  2014
# 5  ktwo201912552  K2VARCAT    HLSP        1   1800.0       0.0  2014
#
#                              description
# 0    Lightcurve Long Cadence (KLC) - C01
# 1  Target Pixel Long Cadence (KTL) - C01
# 2                                   FITS
# 3                                   FITS
# 4                                    PDF
# 5                                   FITS
